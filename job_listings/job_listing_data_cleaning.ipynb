# %% [markdown]
# # Importing dependencies

# %%
import pandas as pd
import numpy as np
from datetime import date,datetime,timedelta
import re

# %% [markdown]
# ## Going through the data

# %%
df = pd.read_csv('naukri_scrapped.csv')

# %%
df.head()
# Out:
#                   Organization     Searched_as  \
# 0                   Persistent  data scientist
# 1                  Oprable Inc  data scientist
# 2  Dreambig It Solutions India  data scientist
# 3                       Axtria  data scientist
# 4                  Evalueserve  data scientist
#
#                                            Job_Title  \
# 0                    Machine Learning (AI) Architect
# 1                                     Data Scientist
# 2  Data Scientist/ Senior Data Scientist/ Manager...
# 3             Patient Analytics and AI/ML/Databricks
# 4  Looking For NLP/Deep Learning Data Scientist F...
#
#                               Location_and_work_mode        Posted  \
# 0  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...  30+ Days Ago
# 1  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...    3 Days Ago
# 2  Noida, Kolkata, Mumbai, Chandigarh, Hyderabad/...      Just Now
# 3  Hybrid - Noida, Uttar Pradesh, Hyderabad/ Secu...   19 Days Ago
# 4  Hybrid - Gurgaon/ Gurugram, Haryana, Bangalore...   19 Days Ago
#
#   Scrapped_Date Experience   Salary_Range
# 0    2023-06-26   5-12 Yrs  Not disclosed
# 1    2023-06-26    0-1 Yrs  Not disclosed
# 2    2023-06-26    1-6 Yrs  Not disclosed
# 3    2023-06-26    4-9 Yrs  Not disclosed
# 4    2023-06-26   7-10 Yrs  Not disclosed

# %%
df.shape
# Out:
# (4000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Organization            4000 non-null   object
#  1   Searched_as             4000 non-null   object
#  2   Job_Title               4000 non-null   object
#  3   Location_and_work_mode  4000 non-null   object
#  4   Posted                  4000 non-null   object
#  5   Scrapped_Date           4000 non-null   object
#  6   Experience              4000 non-null   object
#  7   Salary_Range            4000 non-null   object
# dtypes: object(8)
# memory usage: 250.1+ KB

# %%
df['Salary_Range'].value_counts()
# Out:
# Not disclosed               3601
# 4-6 Lacs PA                   31
# 10-20 Lacs PA                 16
# 20-35 Lacs PA                 14
# 15-30 Lacs PA                 12
#                             ...
# 40-55 Lacs PA                  1
# 70,000-1.25 Lacs PA            1
# 3-6.5 Lacs PA                  1
# 10-13 Lacs PA                  1
# Less than 5,000-5,000 PA       1
# Name: Salary_Range, Length: 151, dtype: int64

# %%
df['Posted'].value_counts()
# Out:
# 30+ Days Ago     1818
# 4 Days Ago        169
# 3 Days Ago        129
# 26 Days Ago       125
# 6 Days Ago        115
# 5 Days Ago        107
# 10 Days Ago       106
# 13 Days Ago       106
# 12 Days Ago       103
# 2 Days Ago        100
# 11 Days Ago        97
# 25 Days Ago        92
# 19 Days Ago        79
# 18 Days Ago        77
# 9 Days Ago         76
# 1 Day Ago          74
# 20 Days Ago        72
# 17 Days Ago        62
# 27 Days Ago        58
# 24 Days Ago        51
# 16 Days Ago        48
# 30 Days Ago        42
# 23 Days Ago        40
# 7 Days Ago         39
# Just Now           37
# 14 Days Ago        30
# 28 Days Ago        28
# 29 Days Ago        26
# Few Hours Ago      23
# 22 Days Ago        21
# 8 Days Ago         20
# 15 Days Ago        18
# 21 Days Ago        12
# Name: Posted, dtype: int64

# %% [markdown]
# # Working on Dates

# %% [markdown]
# ### Date Posted

# %% [markdown]
# Defining a function to get the number of days from the posted column

# %%
def days_ago(text):

    if text == 'Just Now' or text == 'Few Hours Ago':
        return 0
    else:
        number = re.findall(r'\d+',text)[0]
        text = int(number)
        return text

# %%
# days_ago('1 Day Ago ')

# today = datetime.today()

# posting_date = today - timedelta(days=test('30+ days ago'))

# posting_date.strftime("%b %d,%Y")

# %%
df['Days_ago'] = df['Posted'].apply(days_ago)

# %% [markdown]
# Defining a function to get the month and date with respect to current date

# %%
def posting_date(days_):
    
    today = datetime.today()
    posting_date = today - timedelta(days=days_)
    
    return posting_date

# %%
df['Posting_date'] = df['Days_ago'].apply(posting_date)
df['Posting_month'] = df['Posting_date'].dt.strftime('%B') # First getting the month from the Posting Date
df['Posting_date'] = df['Posting_date'].dt.strftime('%B %d,%Y') # Then formatting the Posting Date into Month day, Year format.

# If the Posting_date column is formatted first then getting the month from it will throw an error

# %%
df.head()
# Out:
#                   Organization     Searched_as  \
# 0                   Persistent  data scientist
# 1                  Oprable Inc  data scientist
# 2  Dreambig It Solutions India  data scientist
# 3                       Axtria  data scientist
# 4                  Evalueserve  data scientist
#
#                                            Job_Title  \
# 0                    Machine Learning (AI) Architect
# 1                                     Data Scientist
# 2  Data Scientist/ Senior Data Scientist/ Manager...
# 3             Patient Analytics and AI/ML/Databricks
# 4  Looking For NLP/Deep Learning Data Scientist F...
#
#                               Location_and_work_mode        Posted  \
# 0  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...  30+ Days Ago
# 1  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...    3 Days Ago
# 2  Noida, Kolkata, Mumbai, Chandigarh, Hyderabad/...      Just Now
# 3  Hybrid - Noida, Uttar Pradesh, Hyderabad/ Secu...   19 Days Ago
# 4  Hybrid - Gurgaon/ Gurugram, Haryana, Bangalore...   19 Days Ago
#
#   Scrapped_Date Experience   Salary_Range  Days_ago  Posting_date  \
# 0    2023-06-26   5-12 Yrs  Not disclosed        30   May 28,2023
# 1    2023-06-26    0-1 Yrs  Not disclosed         3  June 24,2023
# 2    2023-06-26    1-6 Yrs  Not disclosed         0  June 27,2023
# 3    2023-06-26    4-9 Yrs  Not disclosed        19  June 08,2023
# 4    2023-06-26   7-10 Yrs  Not disclosed        19  June 08,2023
#
#   Posting_month
# 0           May
# 1          June
# 2          June
# 3          June
# 4          June

# %%
# Dropping the Days_ago column

df.drop('Days_ago',axis=1,inplace=True)

# %%
# df.columns

# %%
# rearranged_cols = ['Organization', 'Searched_as', 'Job_Title', 'Location_and_work_mode', 'Posted', 'Posting_date',
#                    'Posting_month','Scrapped_Date', 'Experience', 'Salary_Range']
# df = df[rearranged_cols]

# %%
df.head()
# Out:
#                   Organization     Searched_as  \
# 0                   Persistent  data scientist
# 1                  Oprable Inc  data scientist
# 2  Dreambig It Solutions India  data scientist
# 3                       Axtria  data scientist
# 4                  Evalueserve  data scientist
#
#                                            Job_Title  \
# 0                    Machine Learning (AI) Architect
# 1                                     Data Scientist
# 2  Data Scientist/ Senior Data Scientist/ Manager...
# 3             Patient Analytics and AI/ML/Databricks
# 4  Looking For NLP/Deep Learning Data Scientist F...
#
#                               Location_and_work_mode        Posted  \
# 0  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...  30+ Days Ago
# 1  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...    3 Days Ago
# 2  Noida, Kolkata, Mumbai, Chandigarh, Hyderabad/...      Just Now
# 3  Hybrid - Noida, Uttar Pradesh, Hyderabad/ Secu...   19 Days Ago
# 4  Hybrid - Gurgaon/ Gurugram, Haryana, Bangalore...   19 Days Ago
#
#   Scrapped_Date Experience   Salary_Range  Posting_date Posting_month
# 0    2023-06-26   5-12 Yrs  Not disclosed   May 28,2023           May
# 1    2023-06-26    0-1 Yrs  Not disclosed  June 24,2023          June
# 2    2023-06-26    1-6 Yrs  Not disclosed  June 27,2023          June
# 3    2023-06-26    4-9 Yrs  Not disclosed  June 08,2023          June
# 4    2023-06-26   7-10 Yrs  Not disclosed  June 08,2023          June

# %% [markdown]
# ## Work Modes and Locations

# %% [markdown]
# Defining a function to get the work mode from the column

# %%
def work_mode(text):

    if 'Hybrid' in text:
        return text.split('-')[0].replace(' ','')
    elif 'Temp. WFH' in text:
        return text.split('-')[0].replace(' ','')
    else:
        return 'WFO'

# %%
df['Work_mode'] = df['Location_and_work_mode'].apply(work_mode)

# %%
df['Work_mode'].value_counts()
# Out:
# WFO         3808
# Hybrid       160
# Temp.WFH      32
# Name: Work_mode, dtype: int64

# %%
df.head(50)
# Out:
#                        Organization     Searched_as  \
# 0                        Persistent  data scientist
# 1                       Oprable Inc  data scientist
# 2       Dreambig It Solutions India  data scientist
# 3                            Axtria  data scientist
# 4                       Evalueserve  data scientist
# 5                         Blackbuck  data scientist
# 6                             Paytm  data scientist
# 7                             Paytm  data scientist
# 8                      AVE Promagne  data scientist
# 9                          Analytos  data scientist
# 10  AVE-Promagne Business Solutions  data scientist
# 11                     AVE Promagne  data scientist
# 12                       Saleswhale  data scientist
# 13                        Accenture  data scientist
# 14                         Sun Life  data scientist
# 15               Bajaj Finserv Ltd.  data scientist
# 16                   Okda Solutions  data scientist
# 17                     Primo Hiring  data scientist
# 18                   Okda Solutions  data scientist
# 19                            Attri  data scientist
# 20                            Attri  data scientist
# 21                         Tredence  data scientist
# 22                           Turing  data scientist
# 23                           Turing  data scientist
# 24                         Skillety  data scientist
# 25                         Clarifai  data scientist
# 26  Glossaread Technologies Pvt Ltd  data scientist
# 27            IBS Software Services  data scientist
# 28                  Corporate Steps  data scientist
# 29                    Agilon Health  data scientist
# 30                         Analytos  data scientist
# 31                   WSD Consultant  data scientist
# 32                    Open Insights  data scientist
# 33                    Scribble Data  data scientist
# 34           Intellect Design Arena  data scientist
# 35                       Innovaccer  data scientist
# 36  Tata Consultancy Services (TCS)  data scientist
# 37          R Systems International  data scientist
# 38                         Infogain  data scientist
# 39                           Adidas  data scientist
# 40                           Adidas  data scientist
# 41                       Innovaccer  data scientist
# 42                        Accenture  data scientist
# 43                              EXL  data scientist
# 44                      Evalueserve  data scientist
# 45                             KPMG  data scientist
# 46                           Adidas  data scientist
# 47           Agile Airport Services  data scientist
# 48                         Ericsson  data scientist
# 49                     Rpa Infotech  data scientist
#
#                                             Job_Title  \
# 0                     Machine Learning (AI) Architect
# 1                                      Data Scientist
# 2   Data Scientist/ Senior Data Scientist/ Manager...
# 3              Patient Analytics and AI/ML/Databricks
# 4   Looking For NLP/Deep Learning Data Scientist F...
# 5                                      Data Scientist
# 6                       Data Science - Technical Lead
# 7             Data Science - Senior Software Engineer
# 8               Sr. Data Scientist - Python / ML / DL
# 9                               Junior Data Scientist
# 10                  Sr Data Scientist (ML / CV / NLP)
# 11                       Data Scientist- Python/ML/DL
# 12                              Senior Data Scientist
# 13                   Analystics & Modeling Specialist
# 14                 Data Scientist || Immediate Joiner
# 15             Deputy Area Manager - B2C Underwriting
# 16                          Data Scientist - R/Python
# 17                  Data Scientist - Engine Algorithm
# 18                          Data Scientist - R/Python
# 19                                 Sr. Data Scientist
# 20                                 Research Scientist
# 21                     Senior Data Scientist - Retail
# 22                             Product Data Scientist
# 23                                   Data Scientist-4
# 24                                       Data Science
# 25                                     Data Scientist
# 26              Senior Deep Learning / Data Scientist
# 27                                     Data Scientist
# 28                              Senior Data Scientist
# 29                           Principal Data Scientist
# 30                                     Data Scientist
# 31                                     Data Scientist
# 32                                     Data Scientist
# 33                                 Solution Architect
# 34                                     Data Scientist
# 35                                     Data Scientist
# 36                                     Data Scientist
# 37                    Lead Data Scientist- 4 Openings
# 38                   Hiring For Senior Data Scientist
# 39                                     Data Scientist
# 40                              Junior Data Scientist
# 41                                     Data Scientist
# 42                            Specialist-Data Science
# 43                                     Senior Manager
# 44  Looking For Data Scientist (Finance Background...
# 45               Advisory-Management-P Data Scientist
# 46                              Junior Data Scientist
# 47                                     Data Scientist
# 48                                     Data Scientist
# 49                  Data Scientist - Machine Learning
#
#                                Location_and_work_mode        Posted  \
# 0   Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...  30+ Days Ago
# 1   Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...    3 Days Ago
# 2   Noida, Kolkata, Mumbai, Chandigarh, Hyderabad/...      Just Now
# 3   Hybrid - Noida, Uttar Pradesh, Hyderabad/ Secu...   19 Days Ago
# 4   Hybrid - Gurgaon/ Gurugram, Haryana, Bangalore...   19 Days Ago
# 5               Gurgaon/Gurugram, Bangalore/Bengaluru  30+ Days Ago
# 6                          Noida, Bangalore/Bengaluru  30+ Days Ago
# 7                          Noida, Bangalore/Bengaluru  30+ Days Ago
# 8   Noida, Mumbai, Chandigarh, Hyderabad/Secundera...    4 Days Ago
# 9   Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...  30+ Days Ago
# 10       Mumbai, New Delhi, Pune, Bangalore/Bengaluru    4 Days Ago
# 11  Noida, Mumbai, Pune, Chennai, Bangalore/Bengal...    4 Days Ago
# 12  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...    9 Days Ago
# 13  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,
# 43       WFO
# 44    Hybrid
# 45       WFO
# 46       WFO
# 47       WFO
# 48       WFO
# 49       WFO

# %% [markdown]
# Defining a function to get the first of all the Locations

# %%
def location(text):
    if 'Hybrid' in text:
        text = text.split('-')[1]
        loc = text.split(',')[0].replace(' ','')
        return loc
    elif 'Temp. WFH' in text:
        text = text.split('-')[1]
        loc = text.split(',')[0].replace(' ','')
        return loc
    else:
        loc = text.split(',')[0].replace(' ','')
        return loc

# %% [markdown]
# A function to clean the location column

# %%
def cleaned_loc(text):
    
    if 'Bangalore/Bengaluru' in text:
        return 'Bengaluru'
    elif 'Gurgaon/Gurugram' in text or 'Gurgaon' in text:
        return 'Gurugram'
    elif 'Hyderabad/Secunderabad' in text:
        return 'Hyderabad'
    elif 'Delhi' in text or 'delhi' in text:
        return 'Delhi'
    elif 'GreaterNoida' in text:
        return 'Noida'
    elif 'Mumbai' in text:
        return 'Mumbai'
    elif 'Cochin' in text or 'Ernakulam' in text:
        return 'Kochi'
    elif 'remote' in text:
        return 'Remote'
    else:
        return text.capitalize()

# %%
df['Location'] = df['Location_and_work_mode'].apply(location)
df['Location'] = df['Location'].apply(cleaned_loc)

# %%
df.head()
# Out:
#                   Organization     Searched_as  \
# 0                   Persistent  data scientist
# 1                  Oprable Inc  data scientist
# 2  Dreambig It Solutions India  data scientist
# 3                       Axtria  data scientist
# 4                  Evalueserve  data scientist
#
#                                            Job_Title  \
# 0                    Machine Learning (AI) Architect
# 1                                     Data Scientist
# 2  Data Scientist/ Senior Data Scientist/ Manager...
# 3             Patient Analytics and AI/ML/Databricks
# 4  Looking For NLP/Deep Learning Data Scientist F...
#
#                               Location_and_work_mode        Posted  \
# 0  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...  30+ Days Ago
# 1  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...    3 Days Ago
# 2  Noida, Kolkata, Mumbai, Chandigarh, Hyderabad/...      Just Now
# 3  Hybrid - Noida, Uttar Pradesh, Hyderabad/ Secu...   19 Days Ago
# 4  Hybrid - Gurgaon/ Gurugram, Haryana, Bangalore...   19 Days Ago
#
#   Scrapped_Date Experience   Salary_Range  Posting_date Posting_month  \
# 0    2023-06-26   5-12 Yrs  Not disclosed   May 28,2023           May
# 1    2023-06-26    0-1 Yrs  Not disclosed  June 24,2023          June
# 2    2023-06-26    1-6 Yrs  Not disclosed  June 27,2023          June
# 3    2023-06-26    4-9 Yrs  Not disclosed  June 08,2023          June
# 4    2023-06-26   7-10 Yrs  Not disclosed  June 08,2023          June
#
#   Work_mode  Location
# 0       WFO   Kolkata
# 1       WFO   Kolkata
# 2       WFO     Noida
# 3    Hybrid     Noida
# 4    Hybrid  Gurugram

# %%
# Dropping the Location and work mode column
df.drop('Location_and_work_mode',axis=1,inplace=True)

# %%
pd.DataFrame(df['Job_Title'].value_counts()).head(50)
# Out:
#                                                     Job_Title
# Data Analyst                                              462
# Data Scientist                                            361
# Machine Learning Engineer                                 116
# Senior Data Scientist                                      98
# Record To Report Ops Associate-Record To Report            52
# Machine Learning AI Platform Engineer                      34
# Lead Data Scientist                                        29
# Deputy Area Manager - B2C Underwriting Rural               28
# Senior Machine Learning Engineer                           28
# Team Lead(AI/ML/Data Learning)                             27
# Natural Language Processing (NLP) AI Platform E...         24
# Hiring Freshers /Experience For Global MNC For ...         24
# Sr. Data Scientist                                         19
# Data Engineer                                              17
# Junior Data Scientist                                      17
# Principal Data Scientist                                   15
# Deputy Area Manager - B2C Underwriting                     14
# Record To Report Ops Analyst-Record To Report              14
# Artificial Intelligence Engineer                           14
# ML Engineer                                                12
# AI Data Scientist                                          12
# Data Science Engineer                                      11
# Speech Scientist - Artificial Intelligence/Mach...         11
# Finance Program & Ops Associate-Procure To Pay ...         10
# Machine Learning Scientist                                 10
# Senior Data Analyst                                        10
# DATA ANALYST                                                9
# Senior Scientist/NLP/Machine Learning/Data Mini...          9
# Senior Data Engineer                                        9
# Data Scientist - R/Python                                   9
# Finance Program & Ops Analyst-Record To Report              9
# Machine Learning Developer                                  8
# Data Analyst III                                            8
# Data Science Manager                                        8
# Finance Program & Ops Analyst-Procure To Pay Pr...          8
# Finance Program & Ops Senior Analyst-Record To ...          8
# Data Scientist / Machine Learning                           8
# data analyst                                                8
# Finance Program & Ops Associate-Record To Report            8
# Business Data Analyst                                       8
# Senior AI Data Scientist                                    7
# Data Scientist / ML Engineer - US MNC (analytics)           7
# Finance Program & Ops Analyst-Finance Processes             7
# Finance Program & Ops Senior Analyst-Finance Pr...          7
# ML Ops Engineer                                             7
# Record To Report Ops New Associate-Record To Re...          7
# Finance Program & Ops Associate Manager-Finance...          7
# Senior ML Engineer                                          7
# Data Scientist - Machine Learning                           7
# Finance Program & Ops Associate-Finance Processes           6

# %% [markdown]
# ## The Job Title

# %% [markdown]
# Defining a function to get the general job title

# %%
def job_title(text):
    
    text = text.lower()
    
    if 'scientist' in text or 'science' in text:
        return 'Data Scientist'
    elif 'analy' in text : #or 'analytics' in text:
        return 'Data Analyst'
    elif 'data engineer' in text or 'service' in text:
        return 'Data Engineer'
    elif 'machine learning' in text or 'ml' in text:
        return 'ML Engineer'
    elif 'nlp' in text or 'deep' in text:
        return 'DL Engineer'
    elif 'ai' in text or 'artificial' in text:
        return 'AI Ops'
    elif 'ops' in text:
        return 'ML Ops'
    elif 'python' in text:
        return 'Python Developer'
    elif 'software' in text:
        return 'Software Engineer'
    else:
        return text.capitalize()

# %%
df['Title'] = df['Job_Title'].apply(job_title)

# %%
pd.DataFrame(df['Title'].value_counts()).head(30)
# Out:
#                                                     Title
# Data Scientist                                       1352
# Data Analyst                                         1020
# ML Engineer                                           765
# ML Ops                                                278
# AI Ops                                                133
# Data Engineer                                         109
# Deep Learning Engineer                                 46
# Deputy area manager - b2c underwriting rural           28
# Hiring freshers /experience for global mnc for ...     24
# Deputy area manager - b2c underwriting                 14
# Python Developer                                       13
# Software Engineer                                      12
# Practitioner - finance and administration delivery      6
# Deputy manager - b2c underwriting rural                 6
# Manager - b2c underwriting rural                        5
# Intern                                                  4
# Assistant manager/ assistant manager bpo/am ope...      3
# Lead - finance and administration delivery              3
# Solution architect                                      3
# Deputy manager - b2c underwriting                       3
# Junior frontend engineer                                2
# Senior manager                                          2
# Content writer                                          2
# Operation coordinator internship                        2
# Background verification internship                      2
# Data mining and algorithm senior engineer               2
# Emergency recovery leader                               2
# Aws data architect(associate director)                  2
# Data specialist                                         2
# Senior manager - quantum computing                      2

# %%
df.head()
# Out:
#                   Organization     Searched_as  \
# 0                   Persistent  data scientist
# 1                  Oprable Inc  data scientist
# 2  Dreambig It Solutions India  data scientist
# 3                       Axtria  data scientist
# 4                  Evalueserve  data scientist
#
#                                            Job_Title        Posted  \
# 0                    Machine Learning (AI) Architect  30+ Days Ago
# 1                                     Data Scientist    3 Days Ago
# 2  Data Scientist/ Senior Data Scientist/ Manager...      Just Now
# 3             Patient Analytics and AI/ML/Databricks   19 Days Ago
# 4  Looking For NLP/Deep Learning Data Scientist F...   19 Days Ago
#
#   Scrapped_Date Experience   Salary_Range  Posting_date Posting_month  \
# 0    2023-06-26   5-12 Yrs  Not disclosed   May 28,2023           May
# 1    2023-06-26    0-1 Yrs  Not disclosed  June 24,2023          June
# 2    2023-06-26    1-6 Yrs  Not disclosed  June 27,2023          June
# 3    2023-06-26    4-9 Yrs  Not disclosed  June 08,2023          June
# 4    2023-06-26   7-10 Yrs  Not disclosed  June 08,2023          June
#
#   Work_mode  Location           Title
# 0       WFO   Kolkata     ML Engineer
# 1       WFO   Kolkata  Data Scientist
# 2       WFO     Noida  Data Scientist
# 3    Hybrid     Noida    Data Analyst
# 4    Hybrid  Gurugram  Data Scientist

# %% [markdown]
# columns to drop:
# Job_title,
# Posted

# %%
df.drop(['Job_Title','Posted'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                   Organization     Searched_as Scrapped_Date Experience  \
# 0                   Persistent  data scientist    2023-06-26   5-12 Yrs
# 1                  Oprable Inc  data scientist    2023-06-26    0-1 Yrs
# 2  Dreambig It Solutions India  data scientist    2023-06-26    1-6 Yrs
# 3                       Axtria  data scientist    2023-06-26    4-9 Yrs
# 4                  Evalueserve  data scientist    2023-06-26   7-10 Yrs
#
#     Salary_Range  Posting_date Posting_month Work_mode  Location  \
# 0  Not disclosed   May 28,2023           May       WFO   Kolkata
# 1  Not disclosed  June 24,2023          June       WFO   Kolkata
# 2  Not disclosed  June 27,2023          June       WFO     Noida
# 3  Not disclosed  June 08,2023          June    Hybrid     Noida
# 4  Not disclosed  June 08,2023          June    Hybrid  Gurugram
#
#             Title
# 0     ML Engineer
# 1  Data Scientist
# 2  Data Scientist
# 3    Data Analyst
# 4  Data Scientist

# %%
df[['Minimum_experience', 'Maximum_experience']] = df['Experience'].str.extract(r'(\d+)-(\d+)')
df[['Minimum_experience', 'Maximum_experience']] = df[['Minimum_experience', 'Maximum_experience']].astype(float)

# %%
df.head()
# Out:
#                   Organization     Searched_as Scrapped_Date Experience  \
# 0                   Persistent  data scientist    2023-06-26   5-12 Yrs
# 1                  Oprable Inc  data scientist    2023-06-26    0-1 Yrs
# 2  Dreambig It Solutions India  data scientist    2023-06-26    1-6 Yrs
# 3                       Axtria  data scientist    2023-06-26    4-9 Yrs
# 4                  Evalueserve  data scientist    2023-06-26   7-10 Yrs
#
#     Salary_Range  Posting_date Posting_month Work_mode  Location  \
# 0  Not disclosed   May 28,2023           May       WFO   Kolkata
# 1  Not disclosed  June 24,2023          June       WFO   Kolkata
# 2  Not disclosed  June 27,2023          June       WFO     Noida
# 3  Not disclosed  June 08,2023          June    Hybrid     Noida
# 4  Not disclosed  June 08,2023          June    Hybrid  Gurugram
#
#             Title  Minimum_experience  Maximum_experience
# 0     ML Engineer                 5.0                12.0
# 1  Data Scientist                 0.0                 1.0
# 2  Data Scientist                 1.0                 6.0
# 3    Data Analyst                 4.0                 9.0
# 4  Data Scientist                 7.0                10.0

# %%
df.columns
# Out:
# Index(['Organization', 'Searched_as', 'Scrapped_Date', 'Experience',
#        'Salary_Range', 'Posting_date', 'Posting_month', 'Work_mode',
#        'Location', 'Title', 'Minimum_experience', 'Maximum_experience'],
#       dtype='object')

# %%
rearranged_cols = ['Organization', 'Searched_as','Title', 'Work_mode', 'Location', 
                   'Posting_date', 'Posting_month','Scrapped_Date',
                   'Experience','Minimum_experience', 'Maximum_experience','Salary_Range']

# %%
df = df[rearranged_cols]

# %%
df.shape
# Out:
# (4000, 12)

# %%
df.head()
# Out:
#                   Organization     Searched_as           Title Work_mode  \
# 0                   Persistent  data scientist     ML Engineer       WFO
# 1                  Oprable Inc  data scientist  Data Scientist       WFO
# 2  Dreambig It Solutions India  data scientist  Data Scientist       WFO
# 3                       Axtria  data scientist    Data Analyst    Hybrid
# 4                  Evalueserve  data scientist  Data Scientist    Hybrid
#
#    Location  Posting_date Posting_month Scrapped_Date Experience  \
# 0   Kolkata   May 28,2023           May    2023-06-26   5-12 Yrs
# 1   Kolkata  June 24,2023          June    2023-06-26    0-1 Yrs
# 2     Noida  June 27,2023          June    2023-06-26    1-6 Yrs
# 3     Noida  June 08,2023          June    2023-06-26    4-9 Yrs
# 4  Gurugram  June 08,2023          June    2023-06-26   7-10 Yrs
#
#    Minimum_experience  Maximum_experience   Salary_Range
# 0                 5.0                12.0  Not disclosed
# 1                 0.0                 1.0  Not disclosed
# 2                 1.0                 6.0  Not disclosed
# 3                 4.0                 9.0  Not disclosed
# 4                 7.0                10.0  Not disclosed

# %% [markdown]
# ### Saving as csv

# %%
df.to_csv('naukri_cleaned.csv',index=False)

# %%
job_titles = ['Data Scientist','Data Analyst','Data Engineer','ML Engineer','Deep Learning Engineer',
              'AI Engineer','ML Ops','Python Developer','Software Engineer']

a = df[df['Title'].isin(job_titles)]

# %%
a.shape
# Out:
# (3595, 12)
